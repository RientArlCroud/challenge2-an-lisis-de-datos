# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ### Ingresos totales por tienda

# %% [markdown]
# 1. tienda 1:

# %%
ing_totales_tienda1 = tienda['Precio'].sum()
print(f"El ingreso total de la tienda 1 es: {ing_totales_tienda1}")
# Out:
# El ingreso total de la tienda 1 es: 1150880400.0

# %% [markdown]
# 2. tienda 2:

# %%
ing_totales_tienda2 = tienda2['Precio'].sum()
print(f"El ingreso total de la tienda 2 es: {ing_totales_tienda2}")
# Out:
# El ingreso total de la tienda 2 es: 1116343500.0

# %% [markdown]
# 3. tienda 3:

# %%
ing_totales_tienda3 = tienda3['Precio'].sum()
print(f"El ingreso total de la tienda 3 es: {ing_totales_tienda3}")
# Out:
# El ingreso total de la tienda 3 es: 1098019600.0

# %% [markdown]
# 4. tienda 4:

# %%
ing_totales_tienda4 = tienda4['Precio'].sum()
print(f"El ingreso total de la tienda 4 es: {ing_totales_tienda4}")
# Out:
# El ingreso total de la tienda 4 es: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ### Cantidad de productos vendidos por categoría en cada tienda

# %% [markdown]
# 1. tienda 1:

# %%
productos_categoria = tienda['Categoría del Producto'].value_counts()
print(productos_categoria)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
venta_cat = tienda.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)
print(venta_cat)
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             429493500.0
# Electrodomésticos        363685200.0
# Muebles                  187633700.0
# Instrumentos musicales    91299000.0
# Deportes y diversión      39290000.0
# Juguetes                  17995700.0
# Artículos para el hogar   12698400.0
# Libros                     8784900.0

# %% [markdown]
# 2. tienda 2:

# %%
productos_categoria2 = tienda2['Categoría del Producto'].value_counts()
print(productos_categoria2)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
venta_cat2 = tienda2.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)
print(venta_cat2)
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410831100.0
# Electrodomésticos        348567800.0
# Muebles                  176426300.0
# Instrumentos musicales   104990300.0
# Deportes y diversión      34744500.0
# Juguetes                  15945400.0
# Artículos para el hogar   14746900.0
# Libros                    10091200.0

# %% [markdown]
# 3. tienda 3:

# %%
productos_categoria3 = tienda3['Categoría del Producto'].value_counts()
print(productos_categoria3)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
venta_cat3 = tienda3.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)
print(venta_cat3)
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             410775800.0
# Electrodomésticos        329237900.0
# Muebles                  201072100.0
# Instrumentos musicales    77380900.0
# Deportes y diversión      35593100.0
# Juguetes                  19401100.0
# Artículos para el hogar   15060000.0
# Libros                     9498700.0

# %% [markdown]
# 4. tienda 4:

# %%
productos_categoria4 = tienda4['Categoría del Producto'].value_counts()
print(productos_categoria4)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
venta_cat4 = tienda4.groupby('Categoría del Producto')[['Precio']].sum().sort_values('Precio', ascending=False)
print(venta_cat4)
# Out:
#                               Precio
# Categoría del Producto
# Electrónicos             409476100.0
# Electrodomésticos        283260200.0
# Muebles                  192528900.0
# Instrumentos musicales    75102400.0
# Deportes y diversión      33350100.0
# Juguetes                  20262200.0
# Artículos para el hogar   15074500.0
# Libros                     9321300.0

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ### Cuál es la satisfacción de los clientes en cada tienda

# %% [markdown]
# 1. tienda 1:

# %%
promedio_calificacion = round(tienda['Calificación'].sum()/len(tienda), 2)
print(f"El promedio de la calificación de los clientes en la tienda uno es: {promedio_calificacion}")
# Out:
# El promedio de la calificación de los clientes en la tienda uno es: 3.98

# %% [markdown]
# 2. tienda 2:

# %%
promedio_calificacion2 = round(tienda2['Calificación'].sum()/len(tienda2), 2)
print(f"El promedio de la calificación de los clientes en la tienda dos es: {promedio_calificacion2}")
# Out:
# El promedio de la calificación de los clientes en la tienda dos es: 4.04

# %% [markdown]
# 3. tienda 3:

# %%
promedio_calificacion3 = round(tienda3['Calificación'].sum()/len(tienda3), 2)
print(f"El promedio de la calificación de los clientes en la tienda tres es: {promedio_calificacion3}")
# Out:
# El promedio de la calificación de los clientes en la tienda tres es: 4.05

# %% [markdown]
# 4. tienda 4:

# %%
promedio_calificacion4 = round(tienda4['Calificación'].sum()/len(tienda4), 2)
print(f"El promedio de la calificación de los clientes en la tienda cuatro es: {promedio_calificacion4}")
# Out:
# El promedio de la calificación de los clientes en la tienda cuatro es: 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# 1. tienda 1:

# %%
productos_vendidos = tienda['Producto'].value_counts()
max_vendido = productos_vendidos.idxmax()
min_vendido = productos_vendidos.idxmin()
print(f"El producto más vendido es: {max_vendido}")
print(f"El producto menos vendido es: {min_vendido}")
# Out:
# El producto más vendido es: Microondas
# El producto menos vendido es: Auriculares con micrófono

# %% [markdown]
# 2. tienda 2:

# %%
productos_vendidos2 = tienda2['Producto'].value_counts()
max_vendido = productos_vendidos2.idxmax()
min_vendido = productos_vendidos2.idxmin()
print(f"El producto más vendido es: {max_vendido}")
print(f"El producto menos vendido es: {min_vendido}")
# Out:
# El producto más vendido es: Iniciando en programación
# El producto menos vendido es: Juego de mesa

# %% [markdown]
# 3. tienda 3:

# %%
productos_vendidos3 = tienda3['Producto'].value_counts()
max_vendido = productos_vendidos3.idxmax()
min_vendido = productos_vendidos3.idxmin()
print(f"El producto más vendido es: {max_vendido}")
print(f"El producto menos vendido es: {min_vendido}")
# Out:
# El producto más vendido es: Kit de bancas
# El producto menos vendido es: Bloques de construcción

# %% [markdown]
# 4. tienda 4:

# %%
productos_vendidos4 = tienda4['Producto'].value_counts()
max_vendido = productos_vendidos4.idxmax()
min_vendido = productos_vendidos4.idxmin()
print(f"El producto más vendido es: {max_vendido}")
print(f"El producto menos vendido es: {min_vendido}")
# Out:
# El producto más vendido es: Cama box
# El producto menos vendido es: Guitarra eléctrica

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ### Cuál es el valor promedio que debe pagar el cliente por envío en cada tienda

# %% [markdown]
# 1. tienda 1:

# %%
promedio_envio = round(tienda['Costo de envío'].mean(), 2)
print(f"El valor promedio que debe pagar el cliente por envío en la tienda uno es: {promedio_envio}")
# Out:
# El valor promedio que debe pagar el cliente por envío en la tienda uno es: 26018.61

# %% [markdown]
# 2. tienda 2:

# %%
promedio_envio2 = round(tienda2['Costo de envío'].mean(), 2)
print(f"El valor promedio que debe pagar el cliente por envío en la tienda dos es: {promedio_envio2}")
# Out:
# El valor promedio que debe pagar el cliente por envío en la tienda dos es: 25216.24

# %% [markdown]
# 3. tienda 3:

# %%
promedio_envio3 = round(tienda3['Costo de envío'].mean(), 2)
print(f"El valor promedio que debe pagar el cliente por envío en la tienda tres es: {promedio_envio3}")
# Out:
# El valor promedio que debe pagar el cliente por envío en la tienda tres es: 24805.68

# %% [markdown]
# 4. tienda 4:

# %%
promedio_envio4 = round(tienda4['Costo de envío'].mean(), 2)
print(f"El valor promedio que debe pagar el cliente por envío en la tienda cuatro es: {promedio_envio4}")
# Out:
# El valor promedio que debe pagar el cliente por envío en la tienda cuatro es: 23459.46

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### Este gráfico va a representar los ingresos de las tiendas por cada año

# %% [markdown]
# 1. tienda 1:

# %%
tienda['Fecha de Compra'] = pd.to_datetime(tienda['Fecha de Compra'], dayfirst=True, errors='coerce')
tienda['Año'] = tienda['Fecha de Compra'].dt.year
ingresos_ct_año = tienda.groupby('Año')[['Precio']].sum()
print(ingresos_ct_año)
# Out:
#            Precio
# Año
# 2020  368933200.0
# 2021  362120800.0
# 2022  316565600.0
# 2023  103260800.0

# %% [markdown]
# 2. tienda 2:

# %%
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'], dayfirst=True, errors='coerce')
tienda2['Año'] = tienda2['Fecha de Compra'].dt.year
ingresos_ct_año2 = tienda2.groupby('Año')[['Precio']].sum()
print(ingresos_ct_año2)
# Out:
#            Precio
# Año
# 2020  320466600.0
# 2021  351215500.0
# 2022  358226500.0
# 2023   86434900.0

# %% [markdown]
# 3. tienda 3:

# %%
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'], dayfirst=True, errors='coerce')
tienda3['Año'] = tienda3['Fecha de Compra'].dt.year
ingresos_ct_año3 = tienda3.groupby('Año')[['Precio']].sum()
print(ingresos_ct_año3)
# Out:
#            Precio
# Año
# 2020  321707500.0
# 2021  362954400.0
# 2022  350438300.0
# 2023   62919400.0

# %% [markdown]
# 4. tienda 4:

# %%
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'], dayfirst=True, errors='coerce')
tienda4['Año'] = tienda4['Fecha de Compra'].dt.year
ingresos_ct_año4 = tienda4.groupby('Año')[['Precio']].sum()
print(ingresos_ct_año4)
# Out:
#            Precio
# Año
# 2020  330847700.0
# 2021  347823600.0
# 2022  302221500.0
# 2023   57482900.0

# %% [markdown]
# ## Vamos a unir todas las tiendas en un solo DF
# ### para eso primero limpiamos los datos

# %%
ingresos_ct_año = ingresos_ct_año.rename(columns={'Precio':'Tienda 1'})
ingresos_ct_año2 = ingresos_ct_año2.rename(columns={'Precio':'Tienda 2'})
ingresos_ct_año3 = ingresos_ct_año3.rename(columns={'Precio':'Tienda 3'})
ingresos_ct_año4 = ingresos_ct_año4.rename(columns={'Precio':'Tienda 4'})

# %%
ventas_tiendas = pd.concat([ingresos_ct_año, ingresos_ct_año2, ingresos_ct_año3, ingresos_ct_año4], axis=1)
ventas_tiendas
# Out:
#          Tienda 1     Tienda 2     Tienda 3     Tienda 4
# Año
# 2020  368933200.0  320466600.0  321707500.0  330847700.0
# 2021  362120800.0  351215500.0  362954400.0  347823600.0
# 2022  316565600.0  358226500.0  350438300.0  302221500.0
# 2023  103260800.0   86434900.0   62919400.0   57482900.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

for tienda in ventas_tiendas.columns:
  plt.plot(
      ventas_tiendas.index,
      ventas_tiendas[tienda],
      marker='o',
      linewidth=2,
      label=tienda
  )

plt.title('Ingresos por tienda a lo largo del tiempo')
plt.xlabel('Año')
plt.ylabel('Ingresos totales (M)')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
ventas_tiendas = ventas_tiendas.drop(2023)

# %%
ventas_millones = ventas_tiendas / 1000000
ventas_millones
# Out:
#       Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Año
# 2020  368.9332  320.4666  321.7075  330.8477
# 2021  362.1208  351.2155  362.9544  347.8236
# 2022  316.5656  358.2265  350.4383  302.2215

# %%
plt.figure(figsize=(12,6))

for tienda in ventas_tiendas.columns:
  plt.plot(
      ventas_tiendas.index,
      ventas_millones[tienda],
      marker='o',
      linewidth=2,
      label=tienda
  )



plt.title('Ingresos por tienda a lo largo del tiempo')
plt.xlabel('Año')
plt.ylabel('Ingresos totales (millones de cop)')
plt.legend()
plt.grid(alpha=0.3)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# 2. Gráfico de envío promedio vs popularidad promedio

# %%
envio_vs_popularidad = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Promedio_envio': [
        promedio_envio,
        promedio_envio2,
        promedio_envio3,
        promedio_envio4
        ],
    'Promedio_calificacion': [
        promedio_calificacion,
        promedio_calificacion2,
        promedio_calificacion3,
        promedio_calificacion4
        ]
})
envio_vs_popularidad
# Out:
#      Tienda  Promedio_envio  Promedio_calificacion
# 0  Tienda 1        26018.61                   3.98
# 1  Tienda 2        25216.24                   4.04
# 2  Tienda 3        24805.68                   4.05
# 3  Tienda 4        23459.46                   4.00

# %%
plt.figure(figsize=(10,8))

plt.scatter(
    envio_vs_popularidad['Promedio_envio'],
    envio_vs_popularidad['Promedio_calificacion'],
    s=100
)

for i, row in envio_vs_popularidad.iterrows():
  offset = (10, 5)

  if row['Tienda'] == 'Tienda 1':
        offset = (-40, 10)

  plt.annotate(
      row['Tienda'],
      (row['Promedio_envio'], row['Promedio_calificacion']),
      textcoords="offset points",
      xytext=offset,
      ha='left'
  )

plt.title("Relación entre costo promedio de envío y calificación promedio")
plt.xlabel("Costo promedio de envío (COP)")
plt.ylabel("Calificación promedio")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# 3. Gráficos pie chart para representar las categorías más y menos vendidas en cada tienda

# %% [markdown]
# 1. tienda 1:

# %%
productos_categoria
plt.figure(figsize=(7,7))
plt.pie(
    productos_categoria,
    labels=productos_categoria.index,
    autopct='%1.1f%%'
)
plt.title('Distribución de productos por categoría - Tienda 1')
plt.show()

# %% [markdown]
# 2. tienda 2:

# %%
productos_categoria2
plt.figure(figsize=(7,7))
plt.pie(
    productos_categoria2,
    labels=productos_categoria2.index,
    autopct='%1.1f%%'
)
plt.title('Distribución de productos por categoría - Tienda 2')
plt.show()

# %% [markdown]
# 3. tienda 3:

# %%
productos_categoria3
plt.figure(figsize=(7,7))
plt.pie(
    productos_categoria3,
    labels=productos_categoria3.index,
    autopct='%1.1f%%'
)
plt.title('Distribución de productos por categoría - Tienda 3')
plt.show()

# %% [markdown]
# 4. tienda 4:

# %%
productos_categoria4
plt.figure(figsize=(7,7))
plt.pie(
    productos_categoria4,
    labels=productos_categoria4.index,
    autopct='%1.1f%%'
)
plt.title('Distribución de productos por categoría - Tienda 4')
plt.show()

# %% [markdown]
# #### Unión de las gráficas

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 12))
fig.subplots_adjust(wspace=0.8)
axs[0, 0].pie(
    productos_categoria,
    labels=productos_categoria.index,
    autopct='%1.1f%%'
)
axs[0, 0].set_title('Distribución de productos por categoría - Tienda 1')

axs[0, 1].pie(
    productos_categoria2,
    labels=productos_categoria2.index,
    autopct='%1.1f%%'
)
axs[0, 1].set_title('Distribución de productos por categoría - Tienda 2')

axs[1, 0].pie(
    productos_categoria3,
    labels=productos_categoria3.index,
    autopct='%1.1f%%'
)
axs[1, 0].set_title('Distribución de productos por categoría - Tienda 3')

axs[1, 1].pie(
    productos_categoria4,
    labels=productos_categoria4.index,
    autopct='%1.1f%%'
)
axs[1, 1].set_title('Distribución de productos por categoría - Tienda 4')

plt.suptitle('Distribución de ventas por categoría - Comparación entre tiendas', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Gráfico de barras para ver el total de las ventas por vendedor en cada tienda

# %% [markdown]
# 1. tienda 1:

# %%
tienda = pd.read_csv(url)
ventas_vendedor = tienda.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=True)
ventas_vendedor['Precio_millones'] = ventas_vendedor['Precio'] / 1_000_000
top5 = ventas_vendedor.sort_values(by='Precio_millones', ascending=True).head(5)

fig, ax = plt.subplots(figsize=(10,8))
top5['Precio_millones'].plot(kind='barh', ax=ax)

ax.set_title("Ventas por vendedor - Tienda 4")
ax.set_xlabel("Ventas (millones de COP)")
ax.set_ylabel("Vendedor")
plt.show()

# %% [markdown]
# 2. tienda 2:

# %%
tienda2 = pd.read_csv(url2)
ventas_vendedor2 = tienda2.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor2['Precio_millones'] = ventas_vendedor2['Precio'] / 1_000_000
top5 = ventas_vendedor2.sort_values(by='Precio_millones', ascending=True).head(5)

fig, ax = plt.subplots(figsize=(10,8))
top5['Precio_millones'].plot(kind='barh', ax=ax)

ax.set_title("Ventas por vendedor - Tienda 4")
ax.set_xlabel("Ventas (millones de COP)")
ax.set_ylabel("Vendedor")
plt.show()

# %% [markdown]
# 3. tienda 3:

# %%
tienda3 = pd.read_csv(url3)
ventas_vendedor3 = tienda3.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor3['Precio_millones'] = ventas_vendedor3['Precio'] / 1_000_000
top5 = ventas_vendedor3.sort_values(by='Precio_millones', ascending=True).head(5)

fig, ax = plt.subplots(figsize=(10,8))
top5['Precio_millones'].plot(kind='barh', ax=ax)

ax.set_title("Ventas por vendedor - Tienda 4")
ax.set_xlabel("Ventas (millones de COP)")
ax.set_ylabel("Vendedor")
plt.show()

# %% [markdown]
# 4. tienda 4:

# %%
import matplotlib.pyplot as plt

tienda4 = pd.read_csv(url4)
ventas_vendedor4 = tienda4.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor4['Precio_millones'] = ventas_vendedor4['Precio'] / 1_000_000
top5 = ventas_vendedor4.sort_values(by='Precio_millones', ascending=True).head(5)

fig, ax = plt.subplots(figsize=(10,8))
top5['Precio_millones'].plot(kind='barh', ax=ax)

ax.set_title("Ventas por vendedor - Tienda 4")
ax.set_xlabel("Ventas (millones de COP)")
ax.set_ylabel("Vendedor")
plt.show()

# %% [markdown]
# ###Unión de las gráficas

# %%
import matplotlib.pyplot as plt
import pandas as pd


# Tienda 1
tienda1_df = pd.read_csv(url)
ventas_vendedor_tienda1 = tienda1_df.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor_tienda1['Precio_millones'] = ventas_vendedor_tienda1['Precio'] / 1_000_000
top5_tienda1 = ventas_vendedor_tienda1.head(5)

# Tienda 2
tienda2_df = pd.read_csv(url2)
ventas_vendedor_tienda2 = tienda2_df.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor_tienda2['Precio_millones'] = ventas_vendedor_tienda2['Precio'] / 1_000_000
top5_tienda2 = ventas_vendedor_tienda2.head(5)

# Tienda 3
tienda3_df = pd.read_csv(url3)
ventas_vendedor_tienda3 = tienda3_df.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor_tienda3['Precio_millones'] = ventas_vendedor_tienda3['Precio'] / 1_000_000
top5_tienda3 = ventas_vendedor_tienda3.head(5)

# Tienda 4
tienda4_df = pd.read_csv(url4)
ventas_vendedor_tienda4 = tienda4_df.groupby('Vendedor')[['Precio']].sum().sort_values('Precio', ascending=False)
ventas_vendedor_tienda4['Precio_millones'] = ventas_vendedor_tienda4['Precio'] / 1_000_000
top5_tienda4 = ventas_vendedor_tienda4.head(5)

fig, axs = plt.subplots(2, 2, figsize=(18, 14))
fig.suptitle('Top 5 Vendedores por Tienda', fontsize=20, y=1.02)

# Plot for Tienda 1
top5_tienda1['Precio_millones'].plot(kind='barh', ax=axs[0, 0])
axs[0, 0].set_title('Top 5 Vendedores - Tienda 1')
axs[0, 0].set_xlabel('Ventas (millones de COP)')
axs[0, 0].set_ylabel('Vendedor')
axs[0, 0].invert_yaxis()

# Plot for Tienda 2
top5_tienda2['Precio_millones'].plot(kind='barh', ax=axs[0, 1])
axs[0, 1].set_title('Top 5 Vendedores - Tienda 2')
axs[0, 1].set_xlabel('Ventas (millones de COP)')
axs[0, 1].set_ylabel('Vendedor')
axs[0, 1].invert_yaxis()

# Plot for Tienda 3
top5_tienda3['Precio_millones'].plot(kind='barh', ax=axs[1, 0])
axs[1, 0].set_title('Top 5 Vendedores - Tienda 3')
axs[1, 0].set_xlabel('Ventas (millones de COP)')
axs[1, 0].set_ylabel('Vendedor')
axs[1, 0].invert_yaxis()

# Plot for Tienda 4
top5_tienda4['Precio_millones'].plot(kind='barh', ax=axs[1, 1])
axs[1, 1].set_title('Top 5 Vendedores - Tienda 4')
axs[1, 1].set_xlabel('Ventas (millones de COP)')
axs[1, 1].set_ylabel('Vendedor')
axs[1, 1].invert_yaxis()

plt.tight_layout()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ed7e102-ea0e-42c8-87dd-8a750c3ba318" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ed7e102-ea0e-42c8-87dd-8a750c3ba318">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  'imagen3.png',
#  '.ipynb_checkpoints',
#  'imagen4.png',
#  'imagen2.png',
#  'imagen1.png',
#  'sample_data']

# %% [markdown]
# # **Informe Final de Análisis de Tiendas - Oracle/Alura**
# **Autor:** Juan Esteban Rodríguez Aranda
#
# **Estudiante G9 - Programa de Análisis de Datos**
# ___
#
# ## **Introducción**
#
# El presente informe tiene como propósito analizar el comportamiento comercial de cuatro tiendas de la compañía del señor Juan. A partir de distintos indicadores, se evaluó el rendimiento histórico de cada tienda, con el fin de determinar cuál de ellas representa la opción menos conveniente para mantener en operación y por lo tante cuál sería la mejor opción para vender.
#
# El análisis realizado parte de las bases de datos suministradas por el programa de formación y se desarrolló utilizando herramientas del ecosistemas de Python, en los Notebook facilitados por Google llamados Colab, particularmente se utilizaron las liberías de Pandas para el procesamiento de datos y Matplotlib para la generación de visualizaciones.
#
# La evaluación se enfoca en cinco componentes clave:
#
# 1. Ingresos totales por tienda a lo largo del tiempo.
# 2. Relación entre costos de envío y calificación promedio.
# 3. Distribución de ventas por categoría de producto.
# 4. Desempeño del equipo comercial (Top 5 vendedores)
# 5. Comparación general para determinar la tienda con menor desempeño relativo.
#
# A continuación se presenta la síntesis de los hallazgos.
#
# ___
#
# ## **1. Ingresos Totales por Tienda en el Tiempo**
#
# El ingreso es un indicador fundamental para evaluar la estabilidad y crecimiento de un establecimiento comercial. Al analizar la tendencia histórica de ventas (2020-2022), se observan diferencias importantes entre las tiendas.
#
# ![imagen](/content/imagen1.png)
#
#
# **Hallazgos:**
# * **Tienda 1** muestra una tendencia decreciente hacia 2022, presentando la caída más pronunciada de todas.
# * **Tienda 2** Mantiene un comportamiento estable y con ligera mejora, lo que indica consistencia.
# * **Tienda 3** presenta un crecimiento significativo entre 2020 y 2021, estabilizándose después con buen desempeño.
# * **Tienda 4** evidencia un descenso considerable en 2022, siendo junto con la Tienda una de las de peor desempeño reciente.
#
# Este panorama permite identificar a la **Tienda 1** y **Tienda 4** como las de menor solidez en ingresos durante el periodo evaluado.
#
# ___
#
# ## **2. Relación entre Costo de Envío y Calificación Promedio**
#
# Permite comprender cómo la experiencia del cliente y los gastos logísticos se comportan juntos. Un buen rendimiento debería combinar costos eficientes con una alta calificación.
#
# <img src="/content/imagen2.png" width="600">
#
# **Hallazgoso:**
#
# * Tienda 3 Logra la mejor conminación: buena calificación y costo de envío moderado.
# * Tienda 2 También presenta calificaciones sólidas con un costo de envío ligeramente más elevado.
# * Tienda 4 Manieten el costo de envío más bajo, pero con una calificación más baja que las demás.
# * Tienda 1 es la que presenta la calificación más baja y el costo de envío más alto simultáneamente.
#
# La tienda 1 es la que más se aleja del equilibrio costo-satisfacción.
#
# ___
#
# ## **3. Distrinución de Ventas por Categoría de Producto**
#
# La diversidad de productos vendidos influye directamente en la estabilidad de ingresos. Las tiendas con ventas equilibradas y categorías fuertes suelen tener un mercado más robusto.
#
# <img src="/content/imagen3.png" width="600">
#
# **Hallazgos:**
#
# * En todas las tiendas, las categorías con mayor participación son Muebles y Electrónicos, manteniendo proporciones similares.
# * Tienda 3 presenta la distribución más equilibrada, evitando la dependencia excesiva de una sola categoría.
# * Tienda 4 depende ligeramente más de una categoría principal y tiene menor participación en categorías secundaias.
# * Tienda 1 muestra una estructura estable, pero no sobresale de forma significativa frente a las demás.
#
# En este punto, ninguna tienda se muestra particularmente débil, pero Tienda 3 destaca por su equilibrio y diversificación.
#
# ___
#
# ## **4. Desempeño de los Vendedores - Top 5 por Tienda**
#
# Las ventas son la clave para sostener el rendimierto comercial de una tienda. Por esta razón compara el desempeño de los mejores vendedores de cada tienda permite ver qué tan competitivo es su talento comercial.
#
# <img src="/content/imagen4.png" width="600">
#
# * Tienda 1 tiene vendedores fuertes, pero sus resultados no logran compensar la caída en ingresos globales.
# * Tienda 2 muestra un equipo comercial sólido y estable.
# * Tienda 3 presenta el mejor desempeño individual: su primer vendedor supera cosistentemente a los de otras tiendas.
# * Tienda 4 tiene vendedores con buen rendimiento, aunque persisten problemas en otros indicadores generales.
#
# En términos de fuerza comercial, Tienda 3 se posiciona nuevamente como la más competitiva.
#
# ___
#
# ## Conlusión y Recomendación Final
#
# Tras analizar los ingresos, niveles de satisfacción del cliente, estructura de ventas por categorías y desempeño de los vendedores, es posible sintetizar el rendimiento de cada tienda:
#
# | **Tienda** | **Ingresos**                   | **Calificación** | **Costo de envío** | **Vendedores**  | **Desempeño general** |
# |-----------|--------------------------------|------------------|---------------------|------------------|-------------------------|
# | **Tienda 1** | Decrecientes y caída fuerte     | Más baja         | Más alto            | Aceptables       | **Más débil**          |
# | **Tienda 2** | Estables y en aumento leve     | Alta             | Competitivo         | Bueno            | **Sólida**             |
# | **Tienda 3** | Robustas                        | Más alta         | Adecuado            | Mejor equipo     | **Mejor tienda**       |
# | **Tienda 4** | Inestables y baja reciente      | Media-baja       | Más bajo            | Aceptables       | **Riesgosa**           |
#
# **Recomendación:**
#
# La tienda que el señor Juan debería considerar vender es la Tienda 1.
#
# #**Justificación**
#
# * Tienda la mayor caída de ingresos hacia el 2022.
# * Posee la calificación promedio más baja entre todas.
# * Presenta el costo de envío más alto, lo que afecta la competitividad.
# * Su equipo comercial no logra compensar la pérdida de rendimiento general.
# * En comparación, Tienda 4, aunque también presenta debilidades, mantiene costos bajos y un mejor potencial de ajuste.
#
# Por esta razón se concluye que la Tienda 1 es la opción menos favorable para conservar, y por lo tanto la mejor elección para ser vendida.

# %%
import os
os.listdir('/content')
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  'fd0279b5-20fa-4063-9d18-fb5886d48397.png',
#  'imagen4.png',
#  'b6b87623-bbfd-4bdc-8645-06af81d4498f.png',
#  'imagen1.png',
#  'sample_data']

# %%
from IPython.display import Image
Image("/content/imagen4.png")
